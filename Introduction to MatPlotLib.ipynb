# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4],[1,4,5,4])
plt.show()

# %%
# 1st Method
fig = plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
#2nd Method
x=[1,2,3,5]
y=[11,21,32,14]
fig = plt.figure()
ax=fig.add_axes([1,~1,1,1])
ax.plot(x,y);

# %%
#3rd recommended
fig,ax= plt.subplots()
ax.plot(x,y)
ax.set(title="Simple plot",
      xlabel='x-axis',
      ylabel="y-axis");

# %%
fig.savefig("images/sample_plpt.png")
